# %%
import numpy as np
from matplotlib import pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
dropout = np.array([np.array([0.0]), np.array([0.1]), np.array([0.2]), np.array([0.0]), np.array([0.1]), np.array([0.2]), np.array([0.0]), np.array([0.1]), np.array([0.2])])
lr = np.array([np.array([0.001]), np.array([0.001]), np.array([0.001]), np.array([0.002]), np.array([0.002]), np.array([0.002]), np.array([0.005]), np.array([0.005]), np.array([0.005])])
test = np.array([np.array([1.2752586603164673]), np.array([1.0518193244934082]), np.array([1.0885690450668335]), np.array([1.3910967111587524]), np.array([1.5094536542892456]), np.array([1.3714627027511597]), np.array([0.0]), np.array([0.0]), np.array([1.3760524988174438])])
train = np.array([np.array([0.4409785270690918]), np.array([0.6128072738647461]), np.array([0.6740688681602478]), np.array([0.8351855874061584]), np.array([0.6979368329048157]), np.array([0.6835834383964539]), np.array([0.0]), np.array([0.0]), np.array([1.0029114484786987])])
print(len(dropout))
print(len(lr))
print(len(test))
plot = plt.figure(figsize=(8, 6))
plot3d = plot.add_subplot(projection='3d')
plot3d.scatter(dropout, lr, test, c = "red")
plot3d.scatter(dropout, lr, train, c = "blue")
plot3d.set_xlabel('dropout')
plot3d.set_ylabel('lr')
plot3d.set_zlabel('loss')
plt.savefig(f'graphs/regression_epochs_50.pdf')
plt.show()
# Out:
# 9
# 9
# 9

# %%
dropout = np.array([np.array([0.0]), np.array([0.1]), np.array([0.2]), np.array([0.0]), np.array([0.1]), np.array([0.2]), np.array([0.0]), np.array([0.1]), np.array([0.2])])
lr = np.array([np.array([0.001]), np.array([0.001]), np.array([0.001]), np.array([0.002]), np.array([0.002]), np.array([0.002]), np.array([0.005]), np.array([0.005]), np.array([0.005])])
test = np.array([np.array([1.4138946533203125]), np.array([1.246757984161377]), np.array([1.2261613607406616]), np.array([1.1054884195327759]), np.array([1.2117012739181519]), np.array([1.0702728033065796]), np.array([1.065117597579956]), np.array([7.588071823120117]), np.array([1.443250060081482])])
train = np.array([np.array([0.17473141849040985]), np.array([0.5486076474189758]), np.array([0.7279052734375]), np.array([0.5591970086097717]), np.array([0.459942489862442]), np.array([0.5309751033782959]), np.array([0.7222324013710022]), np.array([0.7755940556526184]), np.array([0.8382342457771301])])
print(len(dropout))
print(len(lr))
print(len(test))
plot = plt.figure(figsize=(8, 6))
plot3d = plot.add_subplot(projection='3d')
plot3d.scatter(dropout, lr, test, c = "red")
plot3d.scatter(dropout, lr, train, c = "blue")
plot3d.set_xlabel('dropout')
plot3d.set_ylabel('lr')
plot3d.set_zlabel('loss')
plt.savefig(f'graphs/regression_epochs_100.pdf')
plt.show()
# Out:
# 9
# 9
# 9

# %%
dropout = np.array([np.array([0.0]), np.array([0.1]), np.array([0.2]), np.array([0.0]), np.array([0.1]), np.array([0.2]), np.array([0.0]), np.array([0.1]), np.array([0.2])])
lr = np.array([np.array([0.001]), np.array([0.001]), np.array([0.001]), np.array([0.002]), np.array([0.002]), np.array([0.002]), np.array([0.005]), np.array([0.005]), np.array([0.005])])
test = np.array([np.array([0.2800000011920929]), np.array([0.2549999952316284]), np.array([0.22999998927116394]), np.array([0.3400000035762787]), np.array([0.2549999952316284]), np.array([0.26999998092651367]), np.array([0.25]), np.array([0.25]), np.array([0.25])])
train = np.array([np.array([0.5005555748939514]), np.array([0.47611111402511597]), np.array([0.4538888931274414]), np.array([0.5361111164093018]), np.array([0.43611112236976624]), np.array([0.44388890266418457]), np.array([0.4122222363948822]), np.array([0.4122222363948822]), np.array([0.4122222363948822])])
print(len(dropout))
print(len(lr))
print(len(test))
plot = plt.figure(figsize=(8, 6))
plot3d = plot.add_subplot(projection='3d')
plot3d.scatter(dropout, lr, test, c = "red")
plot3d.scatter(dropout, lr, train, c = "blue")
plot3d.set_xlabel('dropout')
plot3d.set_ylabel('lr')
plot3d.set_zlabel('loss')
plt.savefig(f'graphs/classification_epochs_50.pdf')
plt.show()
# Out:
# 9
# 9
# 9

# %%
dropout = np.array([np.array([0.0]), np.array([0.1]), np.array([0.2]), np.array([0.0]), np.array([0.1]), np.array([0.2]), np.array([0.0]), np.array([0.1]), np.array([0.2])])
lr = np.array([np.array([0.001]), np.array([0.001]), np.array([0.001]), np.array([0.002]), np.array([0.002]), np.array([0.002]), np.array([0.005]), np.array([0.005]), np.array([0.005])])
test = np.array([np.array([0.3400000035762787]), np.array([0.3199999928474426]), np.array([0.32999998331069946]), np.array([0.25]), np.array([0.2750000059604645]), np.array([0.28999999165534973]), np.array([0.25]), np.array([0.25]), np.array([0.25])])
train = np.array([np.array([0.6394444704055786]), np.array([0.5900000333786011]), np.array([0.5133333206176758]), np.array([0.41277778148651123]), np.array([0.5149999856948853]), np.array([0.49666666984558105]), np.array([0.39666667580604553]), np.array([0.4122222363948822]), np.array([0.4122222363948822])])
print(len(dropout))
print(len(lr))
print(len(test))
plot = plt.figure(figsize=(8, 6))
plot3d = plot.add_subplot(projection='3d')
plot3d.scatter(dropout, lr, test, c = "red")
plot3d.scatter(dropout, lr, train, c = "blue")
plot3d.set_xlabel('dropout')
plot3d.set_ylabel('lr')
plot3d.set_zlabel('loss')
plt.savefig(f'graphs/classification_epochs_100.pdf')
plt.show()
# Out:
# 9
# 9
# 9

# %%
dropout = np.array([np.array([0.0]), np.array([0.1]), np.array([0.2]), np.array([0.0]), np.array([0.1]), np.array([0.2]), np.array([0.0]), np.array([0.1]), np.array([0.2])])
lr = np.array([np.array([0.001]), np.array([0.001]), np.array([0.001]), np.array([0.002]), np.array([0.002]), np.array([0.002]), np.array([0.005]), np.array([0.005]), np.array([0.005])])
test = np.array([np.array([0.32999998331069946]), np.array([0.3499999940395355]), np.array([0.3449999988079071]), np.array([0.35499998927116394]), np.array([0.3349999785423279]), np.array([0.3149999976158142]), np.array([0.25]), np.array([0.25]), np.array([0.25])])
train = np.array([np.array([0.6516667008399963]), np.array([0.6455555558204651]), np.array([0.5805555582046509]), np.array([0.5655555725097656]), np.array([0.5416666865348816]), np.array([0.5105555653572083]), np.array([0.4122222363948822]), np.array([0.4122222363948822]), np.array([0.4122222363948822])])
print(len(dropout))
print(len(lr))
print(len(test))
plot = plt.figure(figsize=(8, 6))
plot3d = plot.add_subplot(projection='3d')
plot3d.scatter(dropout, lr, test, c = "red")
plot3d.scatter(dropout, lr, train, c = "blue")
plot3d.set_xlabel('dropout')
plot3d.set_ylabel('lr')
plot3d.set_zlabel('loss')
plt.savefig(f'graphs/classification_epochs_150.pdf')
plt.show()
# Out:
# 9
# 9
# 9
